# %% [markdown]
# Day 43 – While Loop, else, break, continue

# %%
import random

secret_number = random.randint(1, 20)
print("Secret number is: ",secret_number)
attempts = 5
count = 0

while attempts > count:
  number = input("Enter a number: ")
  if not number.isdigit():
    print("Invalid input! Please enter a valid number.")
    continue
  number = int(number)

  if number < 0 or number >20:
    print("Your guess is out of range. Please guess a number between 1 and 20.")
    count+=1
    continue
  count+=1

  if number < secret_number:
    print("Too low. Try again")

  elif number > secret_number:
    print("Too high. Try again.")

  else :
    print("Congratulations! You guessed the correct number.")
    break

else:
  print("Better luck next time!,the number is",secret_number)
# Out:
# Secret number is:  8
# Enter a number: 2
# Too low. Try again
# Enter a number: 10
# Too high. Try again.
# Enter a number: 26
# Your guess is out of range. Please guess a number between 1 and 20.
# Enter a number: 22
# Your guess is out of range. Please guess a number between 1 and 20.
# Enter a number: 4
# Too low. Try again
# Better luck next time!,the number is 8
